# %% [markdown]
# <a href="https://colab.research.google.com/github/Squirrelcoding/parking-meter/blob/main/Parking_Meter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %mkdir h5_source_data
# Out:
# mkdir: cannot create directory ‘h5_source_data’: File exists

# %%
# %mkdir car/car_data
# %mkdir car/car_heatmaps
# Out:
# mkdir: cannot create directory ‘car/car_data’: No such file or directory
# mkdir: cannot create directory ‘car/car_heatmaps’: No such file or directory

# %%
# !python3 generate_initial_heatmaps.py
# Out:
# 0 / 51
# ...

# %%
# !python3 generate_dataset.py
# Out:
# Processed 1/51 source images
# Processed 2/51 source images
# Processed 3/51 source images
# Processed 4/51 source images
# Processed 5/51 source images
# Processed 6/51 source images
# Processed 7/51 source images
# Processed 8/51 source images
# Processed 9/51 source images
# Processed 10/51 source images
# ...
# Processed 11/51 source images
# Processed 12/51 source images
# Processed 13/51 source images
# Processed 14/51 source images
# Processed 15/51 source images
# Processed 16/51 source images
# Processed 17/51 source images
# Processed 18/51 source images
# Processed 19/51 source images
# Processed 20/51 source images
# Processed 21/51 source images
# Processed 22/51 source images
# Processed 23/51 source images
# ...
# Processed 24/51 source images
# Processed 25/51 source images
# Processed 26/51 source images
# Processed 27/51 source images
# Processed 28/51 source images
# Processed 29/51 source images
# Processed 30/51 source images
# Processed 31/51 source images
# ...

# %%
# !python3 clean.py
# Out:
# [25, 33, 52, 67, 86, 88, 92, 97, 101, 108, 109, 118, 131, 136, 140, 144, 147, 150, 151, 154, 156, 159, 160, 164, 166, 167, 168, 172, 173, 177, 180, 181, 182, 183, 186, 187, 192, 194, 195, 196, 197, 198, 208, 210, 213, 217, 218, 220, 225, 233, 239, 243, 246, 248, 251, 252, 254, 255, 256, 259, 264, 268, 270, 276, 277, 281, 282, 283, 284, 286, 293, 317, 326, 350, 379, 380, 383, 396, 397, 399, 428, 431, 451, 452, 456, 459, 474, 476, 477, 479, 483, 484, 486, 489, 493, 494, 495, 498, 499, 500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 512, 513, 514, 515, 516, 517, 518, 519, 520, 521, 522, 523, 524, 525, 526, 527, 528, 529, 530, 531, 532, 533, 534, 535, 536, 537, 538, 539, 540, 541, 542, 543, 544, 545, 546, 547, 548, 549, 558, 573, 578, 584, 591, 595, 596, 604, 615, 616, 617, 623, 624, 633, 650, 651, 652, 653, 654, 655, 656, 657, 658, 659, 660, 661, 662, 663, 664, 665, 666, 667, 668, 669, 670, 671, 672, 673, 674, 675, 676, 677, 678, 679, 680, 681, 682, 683, 684, 685, 686, 687, 
# ...

# %%
# !python3 train.py a b 0 0
# Out:
# ['data/car/car_data/0.png', 'data/car/car_data/1.png', 'data/car/car_data/2.png', 'data/car/car_data/3.png', 'data/car/car_data/4.png', 'data/car/car_data/5.png', 'data/car/car_data/6.png', 'data/car/car_data/7.png', 'data/car/car_data/8.png', 'data/car/car_data/9.png', 'data/car/car_data/10.png', 'data/car/car_data/11.png', 'data/car/car_data/12.png', 'data/car/car_data/13.png', 'data/car/car_data/14.png', 'data/car/car_data/15.png', 'data/car/car_data/16.png', 'data/car/car_data/17.png', 'data/car/car_data/18.png', 'data/car/car_data/19.png', 'data/car/car_data/20.png', 'data/car/car_data/21.png', 'data/car/car_data/22.png', 'data/car/car_data/23.png', 'data/car/car_data/24.png', 'data/car/car_data/25.png', 'data/car/car_data/26.png', 'data/car/car_data/27.png', 'data/car/car_data/28.png', 'data/car/car_data/29.png', 'data/car/car_data/30.png', 'data/car/car_data/31.png', 'data/car/car_data/32.png', 'data/car/car_data/33.png', 'data/car/car_data/34.png', 'data/car/car_data/35.png',
# ...

# %%
from pathlib import Path

def count_files(folder_path):
    return sum(1 for f in Path(folder_path).iterdir() if f.is_file())

# Example usage
folder = "data/car/car_data"
print("Number of files:", count_files(folder))
# Out:
# Number of files: 1531
